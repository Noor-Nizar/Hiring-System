# %%
from pyke import knowledge_engine

# Create a new knowledge engine
engine = knowledge_engine.engine()

# Load the knowledge base
engine.activate('hr_expert_system')
def test():
    engine.reset()
    engine.activate()
    print("doing proof ...")
    try:
        with engine.prove.goal()
    

# Define the rules for evaluating applicants
def applicant_suitability(applicant):
    # Initialize the suitability score to 0
    score = 0
    
    # Check the applicant's education and work experience
    if applicant.degree in relevant_degrees:
        score += 1
    if applicant.work_experience > 5:
        score += 1
        
    # Check the applicant's skills and abilities
    for skill in applicant.skills:
        if skill in relevant_skills:
            score += 1
            
    # Check the applicant's personality and fit with company culture
    if applicant.values_align_with_company:
        score += 1
    if applicant.good_communication_skills:
        score += 1
        
    # Return the final score
    return score

# Define the function for making a recommendation
def recommend_applicant(engine, applicant):
    # Get the suitability score for the applicant
    score = applicant_suitability(engine, applicant)
    
    # Make a recommendation based on the score
    if score >= 4:
        return "Recommended"
    elif score >= 2:
        return "Consider"
    else:
        return "Not recommended"

# Create a user interface for inputting applicant information and receiving recommendations
def hr_expert_system_ui():
    # Prompt the user for applicant information
    applicant_name = input("Enter the applicant's name: ")
    applicant_degree = input("Enter the applicant's degree: ")
    applicant_work_experience = input("Enter the applicant's work experience: ")
    applicant_skills = input("Enter the applicant's skills (separated by commas): ").split(',')
    applicant_values_align_with_company = input("Do the applicant's values align with the company's values? (yes/no) ")
    applicant_good_communication_skills = input("Does the applicant have good communication skills? (yes/no) ")
    
    # Create an applicant object with the inputted information
    applicant = Applicant(name=applicant_name, degree=applicant_degree, work_experience=applicant_work_experience,
                         skills=applicant_skills, values_align_with_company=(applicant_values_align_with_company == 'yes'),
                         good_communication_skills=(applicant_good_communication_skills == 'yes'))
    
    # Get the recommendation from the expert system
    recommendation = recommend_applicant(engine, applicant)
    
    # Print the recommendation
    print("Recommendation:", recommendation)

# Run the user interface
hr_expert_system_ui()
